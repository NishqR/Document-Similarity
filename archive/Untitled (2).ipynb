# %%
import pandas as pd
import json

# %%
folder_name = "fwb_data/"
filename = "part-000000000000"
filetype = ".json"
articles_df = pd.read_json(folder_name+filename+filetype, lines=True)
articles_df.fillna("", inplace=True)

# %%
articles_df[0:10].to_csv("labels.csv")

# %%
new_articles_df = pd.read_csv("all_articles_updated.csv")

# %%
new_articles_df.fillna("", inplace=True)
new_articles_df
# Out:
#                                           article_title  \
# 0                Intervention was the right thing to do
# 1     SIX STATES FILE A CHALLENGE TO THE BIDEN ADMIN...
# 2     Senator Reverend Warnock Introduces Bill to En...
# 3     10 Markets Where Sellers Are Cutting Home Pric...
# 4     Biden touts Inflation Reduction Act, critics s...
# ...                                                 ...
# 1450                                EUGENE G. VIGNEAULT
# 1451  COVER STORY: AGENTS WHO TEAM UP SHARING THE WO...
# 1452  WATER, DESTINY HANG ON TALKS \ AS NEGOTIATIONS...
# 1453             LURING MORE SETTLERS TO THE N.C. COAST
# 1454                                        LOCAL SCENE
#
#                                                    text  relevant copyright  \
# 0     News Intervention was the right thing to do FI...         0
# 1     SIX STATES FILE A CHALLENGE TO THE BIDEN ADMIN...         0
# 2     Senator Reverend Warnock Introduces Bill to En...         1
# 3     Daily 10 Markets Where Sellers Are Cutting Hom...         1
# 4     Biden touts Inflation Reduction Act, critics s...         0
# ...                                                 ...       ...       ...
# 1450  EUGENE G. VIGNEAULT Eugene G. Vigneault Sr., 6...         0
# 1451  COVER STORY: AGENTS WHO TEAM UP SHARING THE WO...         0
# 1452  WATER, DESTINY HANG ON TALKS \ AS NEGOTIATIONS...         0
# 1453  LURING MORE SETTLERS TO THE N.C. COAST Over th...         0
# 1454  LOCAL SCENE VIRGINIA BEACH  RUCKER, GRAY AND S...         0
#
#      subject_codes art modification_datetime body  \
# 0
# 1
# 2
# 3
# 4
# ...            ...  ..                   ...  ...
# 1450
# 1451
# 1452
# 1453
# 1454
#
#      company_codes_occur_ticker_exchange company_codes_occur  ... an  \
# 0                                                             ...
# 1                                                             ...
# 2                                                             ...
# 3                                                             ...
# 4                                                             ...
# ...                                  ...                 ...  ... ..
# 1450                                                          ...
# 1451                                                          ...
# 1452                                                          ...
# 1453                                                          ...
# 1454                                                          ...
#
#      word_count company_codes industry_codes title publication_datetime  \
# 0
# 1
# 2
# 3
# 4
# ...         ...           ...            ...   ...                  ...
# 1450
# 1451
# 1452
# 1453
# 1454
#
#      publisher_name action document_type dateline
# 0
# 1
# 2
# 3
# 4
# ...             ...    ...           ...      ...
# 1450
# 1451
# 1452
# 1453
# 1454
#
# [1455 rows x 44 columns]
