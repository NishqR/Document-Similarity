# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
relevant_df = pd.read_csv("relevant_words_count.csv", usecols = ['word', 'frequency'])

# %%
relevant_df
# Out:
#                 word  frequency
# 0            pension        158
# 1         retirement        131
# 2               loan        115
# 3           mortgage        111
# 4              money         99
# ...              ...        ...
# 5364       martineau          1
# 5365  'conversation'          1
# 5366            not"          1
# 5367          strain          1
# 5368        million?          1
#
# [5369 rows x 2 columns]

# %%
#relevant_df.head(30)
#df_sklearn = relevant_df.copy()
  
# apply normalization techniques
apply_scale_column = 'frequency'
relevant_df['frequency_scaled'] = MinMaxScaler().fit_transform(np.array(relevant_df[apply_scale_column]).reshape(-1,1))
  
# view normalized data  
display(relevant_df.head(30))
# Out:
#           word  frequency  frequency_scaled
# 0      pension        158          1.000000
# 1   retirement        131          0.828025
# 2         loan        115          0.726115
# 3     mortgage        111          0.700637
# 4        money         99          0.624204
# 5         rate         95          0.598726
# 6      student         93          0.585987
# 7          pay         90          0.566879
# 8         plan         82          0.515924
# 9          tax         81          0.509554
# 10        debt         78          0.490446
# 11   financial         73          0.458599
# 12       state         69          0.433121
# 13      income         69          0.433121
# 14      saving         67          0.420382
# 15        home         65          0.407643
# 16      worker         61          0.382166
# 17    interest         59          0.369427
# 18      health         58          0.363057
# 19        cent         58          0.363057
# ...

# %%
relevant_df[relevant_df['word'] == 'pension']['frequency'] +=1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_8740\1822988070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relevant_df[relevant_df['word'] == 'pension']['frequency'] +=1

# %%
relevant_df.loc[relevant_df['word'] == 'pension', ['frequency']] += 1

# %%
relevant_df['relevancy_score'] = np.ones(len(relevant_df))

# %%
relevant_df
# Out:
#                 word  frequency  frequency_scaled  relevancy_score  \
# 0            pension        159          1.000000       159.000000
# 1         retirement        131          0.828025       108.471338
# 2               loan        115          0.726115        83.503185
# 3           mortgage        111          0.700637        77.770701
# 4              money         99          0.624204        61.796178
# ...              ...        ...               ...              ...
# 5364       martineau          1          0.000000         0.000000
# 5365  'conversation'          1          0.000000         0.000000
# 5366            not"          1          0.000000         0.000000
# 5367          strain          1          0.000000         0.000000
# 5368        million?          1          0.000000         0.000000
#
#       weighted_score
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# ...

# %%
relevant_df['weighted_score'] = np.ones(len(relevant_df))

# %%
relevant_df['relevancy_score'] = relevant_df['frequency'] * relevant_df['frequency_scaled']

# %%
relevant_df['relevancy_score']
