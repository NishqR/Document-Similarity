# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\nishq\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\nishq\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\nishq\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv('Label_Set_2.csv', encoding = 'utf-8')

# %%
df['text'] = df['snippet'] + '\n' + df['preprocessed_article']

# %%
df = df.rename(columns={'title': 'article_title', 'relevance': 'relevant'})

# %%
df
# Out:
#     article_no                               preprocessed_article  \
# 0      1508707  Nova Scotia Supreme Court Justice Michael Wood...
# 1       992363  SEE ALSO: 7 Worst Mistakes Investors Will Make...
# 2       479667   Robert G. Sharpe, executive vice president, s...
# 3       341850  The easiest way to get going is to open either...
# 4       285847  However, the chancellor said on Monday that th...
# ..         ...                                                ...
# 594    1155796  The new car service lets customers make their ...
# 595    1499757  Gardens are situated at the front and rear of ...
# 596     791726  ECUA Chairwoman Lois Benson and board member D...
# 597     605278                                                NaN
# 598     532542                                                NaN
#
#                                                snippet  \
# 0    Gerald Cotten, the 30-yearold CEO and sole dir...
# 1    No investment is completely safe. You need to ...
# ...

# %%
df = df.drop(df.index[300:400])

# %%
df
# Out:
#     article_no                               preprocessed_article  \
# 0      1508707  Nova Scotia Supreme Court Justice Michael Wood...
# 1       992363  SEE ALSO: 7 Worst Mistakes Investors Will Make...
# 2       479667   Robert G. Sharpe, executive vice president, s...
# 3       341850  The easiest way to get going is to open either...
# 4       285847  However, the chancellor said on Monday that th...
# ..         ...                                                ...
# 594    1155796  The new car service lets customers make their ...
# 595    1499757  Gardens are situated at the front and rear of ...
# 596     791726  ECUA Chairwoman Lois Benson and board member D...
# 597     605278                                                NaN
# 598     532542                                                NaN
#
#                                                snippet  \
# 0    Gerald Cotten, the 30-yearold CEO and sole dir...
# 1    No investment is completely safe. You need to ...
# ...

# %%
df.to_csv('labelled_2.csv')

# %%
# Out:
#     article_no                               preprocessed_article  \
# 260     174930  Read the results in full.  The majority (74%) ...
# 240    1454583  Earlier this year, city officials had estimate...
# 443     274803  Financial advice can encompass a lot of differ...
# 454     294742  BILL SUMMARY:  (This measure has not been amen...
# 425     899739  * He found nobody spoke about the incident whe...
# ..         ...                                                ...
# 185    1219804  It comes as Department for Education (DfE) ana...
# 219     753542  Last month, they started Retirement Specialist...
# 526     971858  There are around 2.6million people still claim...
# 345     402664  He says the actual figure will depend on any d...
# 79      417363  In 2021, the financial services world continue...
#
#                                                snippet  \
# 260  The majority of this week's Pensions Buzz resp...
# 240  The Grand Island City Council members like a p...
# ...
