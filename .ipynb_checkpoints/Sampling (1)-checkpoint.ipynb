# %% [markdown]
# ## Importing libraries/packages

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install nltk
# !pip install gensim
# !pip install spacy
# !pip install pyLDAvis
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz

# %%
import pandas as pd
from gensim.parsing.preprocessing import preprocess_string
from gensim import corpora
import gensim
from gensim.models.coherencemodel import CoherenceModel
import re
# from tabulate import tabulate
import os
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import numpy as np
import json
# import image module
from IPython.display import Image

# %%
# List stop words
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
print(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Reading in the data

# %%
all_df = pd.DataFrame()
for i in os.listdir('./Climate-change-data_uncompressed'):
    print(i)
    read_df = pd.read_json(f'./Climate-change-data_uncompressed/{i}', lines=True)

    all_df = pd.concat([all_df, read_df])
# Out:
# part-000000000000.json
# part-000000000001.json
# part-000000000002.json
# part-000000000003.json
# part-000000000004.json
# part-000000000005.json
# part-000000000006.json
# part-000000000007.json
# part-000000000008.json
# part-000000000009.json
# part-000000000010.json
# part-000000000011.json
# part-000000000012.json
# part-000000000013.json
# part-000000000014.json
# part-000000000015.json
# part-000000000016.json
# part-000000000017.json
# part-000000000018.json
# part-000000000019.json
# part-000000000020.json
# part-000000000021.json
# part-000000000022.json
# part-000000000023.json
# part-000000000024.json
# part-000000000025.json
# part-000000000026.json
# part-000000000027.json
# part-000000000028.json
# part-000000000029.json
# part-000000000030.json
# part-000000000031.json
# part-000000000032.json
# part-000000000033.json
# part-000000000034.json
# part-000000000035.json
# part-000000000036.json
# part-000000000037.json
# part-000000000038.json
# part-000000000039.json
# part-000000000040.json
# part-000000000041.json
# part-000000000042.json
# part-000000000043.json
# part-000000000044.json
# part-000000000045.json
# part-000000000046.json
# part-000000000047.json
# part-000000000048.json
# part-000000000049.json
# part-000000000050.json
# part-000000000051.json
# part-000000000052.json
# part-000000000053.json
# part-000000000054.json
# part-000000000055.json
# part-000000000056.json
# part-000000000057.json
# part-000000000058.json
# part-000000000059.json
# part-000000000060.json
# part-000000000061.json
# part-000000000062.json
# part-000000000063.json
# part-000000000064.json
# part-000000000065.json
# part-000000000066.json
# part-000000000067.json
# part-000000000068.json
# part-000000000069.json
# part-000000000070.json
# part-000000000071.json
# part-000000000072.json
# part-000000000073.json
# part-000000000074.json
# part-000000000075.json
# part-000000000076.json
# part-000000000077.json
# part-000000000078.json
# part-000000000079.json
# part-000000000080.json

# %%
all_df
# Out:
#                                                copyright  \
# 0                    (c) 2009 Dow Jones & Company, Inc.
# 1                   (c) 2004 Dow Jones & Company, Inc.
# 2        \n(Copyright (c) 1993, Dow Jones & Co., Inc.)\n
# 3      Copyright 2019 Dow Jones & Company, Inc. All R...
# 4      Copyright 2022 Dow Jones & Company, Inc. All R...
# ...                                                  ...
# 31340             Copyright © 2021 West Elgin Chronicle
# 31341  Copyright 2022, Hagadone Corporation. All Righ...
# 31342  Copyright 2016, The Weatherford Democrat. All ...
# 31343  Copyright 2017, Waterloo-Cedar Falls Courier. ...
# 31344  Copyright 2015, The Express Star. All Rights R...
#
#                                            subject_codes  art  \
# 0      ,gclimt,genv,gsci,gwea,nlet,nlte,gcat,gglobe,n...
# 1      ,c13,c314,gcat,genv,gverg,mcrntg,nedi,opec,c31...
# 2                                            ,gcat,genv,  NaN
# 3                              ,gclimt,genv,gcat,gglobe,
# 4      ,gpir,gpol,gvote,ncolu,nlet,gcat,ncat,nfact,nf...
# ...                                                  ...  ...
# 31340  ,gclimt,nlet,gcat,genv,gglobe,ncat,nfact,nfce,...
# 31341  ,gnatcn,gdroug,gnrsca,gclimt,nlet,gcat,gdis,ge...
# 31342                          ,gclimt,gcat,genv,gglobe,
# 31343  ,gvlwh,gclimt,gcat,genv,gglobe,gpir,gpol,gvbod...
# 31344  ,gterr,gsoc,gmssh,gclimt,ggaym,gimm,gmurd,gvio...
#
#        modification_datetime  \
# 0              1275316377000
# 1              1084574043000
# 2              1034986381000
# 3              1551138177000
# 4              1667611872000
# ...                      ...
# 31340          1638422916000
# 31341          1646794734000
# 31342          1461943637000
# 31343          1494368093000
# 31344          1451583925000
#
#                                                     body  \
# 0      Lomborg may believe global warming is a seriou...
# 1      If there will ever be a time when the U.S. sho...
# 2      \nWulff made two further errors: We are not be...
# 3      According to the U.S. National Climate Assessm...
# 4      To the Editor: Both parties need to realize th...
# ...                                                  ...
# 31340  Set aside a corner in the living room for Sant...
# 31341  Drought conditions in most of Montana are curr...
# 31342  They have found that reforestation also plays ...
# 31343  The two-term incumbent faced regular interrupt...
# 31344  Attitudes on Same-Sex Marriage by State\n\nFif...
#
#                      company_codes_occur_ticker_exchange  \
# 0
# 1
# 2
# 3
# 4      ,GNGYF:PSGM,GRCH:XFRA,601333:XSHG,0525:XHKG,GO...
# ...                                                  ...
# 31340
# 31341
# 31342
# 31343
# 31344
#
#                                   company_codes_occur company_codes_about  \
# 0
# 1
# 2
# 3                                     ,switcr,ipocch,
# 4      ,onlnfr,imonf,guarly,goog,bisett,applc,amzcom,             ,imonf,
# ...                                               ...                 ...
# 31340
# 31341
# 31342
# 31343
# 31344                           ,euruno,chbdo,aqdirq,            ,aqdirq,
#
#       company_codes_lineage  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 31340
# 31341
# 31342
# 31343
# 31344
#
#                            company_codes_ticker_exchange  ...  \
# 0                                                         ...
# 1                                                         ...
# 2                                                         ...
# 3                                                         ...
# 4      ,GOOG:NEOE,GOOG:XLIM,GOOC:XWBO,0RIH:XLON,GOOGL...  ...
# ...                                                  ...  ...
# 31340                                                     ...
# 31341                                                     ...
# 31342                                                     ...
# 31343                                                     ...
# 31344                                                     ...
#
#                               an word_count  \
# 0      B000000020091010e5ac0000a        259
# 1      B000000020040501e0530000h       1464
# 2      b000000020011031dpbt001fx        195
# 3      B000000020190216ef2i0015v        911
# 4      B000000020221104eib7000p1        951
# ...                          ...        ...
# 31340  WSTELGIN20211202ehc20000h        158
# 31341  WSTNWSMT20220309ei3800007        333
# 31342  WTHFRDDM20160429ec4s00001        473
# 31343  WTRLCDRF20170509ed590003s        826
# 31344  XPRSSTRC20151231ebcu00003        762
#
#                                            company_codes  \
# 0
# 1
# 2
# 3                 ,aupra,bnkeng,bp,ipocch,switcr,switcr,
# 4      ,amzcom,amzcom,applc,applc,bisett,bisett,goog,...
# ...                                                  ...
# 31340
# 31341
# 31342
# 31343                               ,epagy,uscbof,ushor,
# 31344   ,aqdirq,aqdirq,aqdirq,chbdo,chbdo,euruno,euruno,
#
#                          industry_codes  \
# 0
# 1      ,i16101,i13,i15,i1610109,i1,i16,
# 2
# 3
# 4                                  ,i1,
# ...                                 ...
# 31340
# 31341
# 31342
# 31343
# 31344
#
#                                                    title publication_datetime  \
# 0                 Barron's Mailbag: Blowing Hot and Cold        1255305600000
# 1      Unleash the Potential: The benefits of buildin...        1083542400000
# 2          \nBarron's Mailbag:\nMore On Global Warming\n         754531200000
# 3      Climate Change's Risk to Investors --- Why spe...        1550448000000
# 4                    Fossil Fuels Are the Critical Issue        1667779200000
# ...                                                  ...                  ...
# 31340                 Why are we buying Christmas trees?        1638403200000
# 31341  Megadrought highlights need for water conserva...        1646697600000
# 31342  Researcher finds that New Hampshire's growing ...        1461801600000
# 31343                Dubuque town hall puts heat on Blum        1494288000000
# 31344     Visualizations of the top news stories of 2015        1451433600000
#
#                            publisher_name action document_type  \
# 0               Dow Jones & Company, Inc.    rep       article
# 1                     Dow Jones & Company    rep       article
# 2                     Dow Jones & Company    rep       article
# 3               Dow Jones & Company, Inc.    rep       article
# 4               Dow Jones & Company, Inc.    rep       article
# ...                                   ...    ...           ...
# 31340              Postmedia Network Inc.    add       article
# 31341                      Hagadone Corp.    add       article
# 31342  Community Newspaper Holdings, Inc.    add       article
# 31343                     Lee Enterprises    add       article
# 31344  Community Newspaper Holdings, Inc.    add       article
#
#               dateline
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 31340          London
# 31341              NaN
# 31342              NaN
# 31343              NaN
# 31344  Chickaha, OK
#
# [2548107 rows x 41 columns]

# %% [markdown]
# ## Preprocessing the dataset & sampling

# %%
# Run this cell if you find any column names that don't make sense to be used.
# Replace the words 'index' and 'Unnamed: 0' with the names that you want to exclude.

# Drop the column name making less sense  , 'subject_codes'
all_df = all_df.reset_index().drop(columns=['copyright','company_codes_association', 'art', 'modification_datetime', 'company_codes_occur_ticker_exchange', 'company_codes_occur', 'company_codes_about', 'company_codes_lineage','company_codes_ticker_exchange','company_codes_relevance_ticker_exchange','publication_date',	'market_index_codes','credit','section','company_codes_association_ticker_exchange','currency_codes','an','word_count','company_codes','industry_codes','action','document_type','dateline', 'publication_datetime','company_codes_relevance','source_code','person_codes','company_codes_lineage_ticker_exchange','ingestion_datetime','modification_date','company_codes_about_ticker_exchange'])

# %%
all_df
# Out:
#          index                                      subject_codes  \
# 0            0  ,gclimt,genv,gsci,gwea,nlet,nlte,gcat,gglobe,n...
# 1            1  ,c13,c314,gcat,genv,gverg,mcrntg,nedi,opec,c31...
# 2            2                                        ,gcat,genv,
# 3            3                          ,gclimt,genv,gcat,gglobe,
# 4            4  ,gpir,gpol,gvote,ncolu,nlet,gcat,ncat,nfact,nf...
# ...        ...                                                ...
# 2548102  31340  ,gclimt,nlet,gcat,genv,gglobe,ncat,nfact,nfce,...
# 2548103  31341  ,gnatcn,gdroug,gnrsca,gclimt,nlet,gcat,gdis,ge...
# 2548104  31342                          ,gclimt,gcat,genv,gglobe,
# 2548105  31343  ,gvlwh,gclimt,gcat,genv,gglobe,gpir,gpol,gvbod...
# 2548106  31344  ,gterr,gsoc,gmssh,gclimt,ggaym,gimm,gmurd,gvio...
#
#                                                       body  \
# 0        Lomborg may believe global warming is a seriou...
# 1        If there will ever be a time when the U.S. sho...
# 2        \nWulff made two further errors: We are not be...
# 3        According to the U.S. National Climate Assessm...
# 4        To the Editor: Both parties need to realize th...
# ...                                                    ...
# 2548102  Set aside a corner in the living room for Sant...
# 2548103  Drought conditions in most of Montana are curr...
# 2548104  They have found that reforestation also plays ...
# 2548105  The two-term incumbent faced regular interrupt...
# 2548106  Attitudes on Same-Sex Marriage by State\n\nFif...
#
#                                                    snippet region_of_origin  \
# 0        To the Editor:\n\nThe Sept. 28 article "A Smar...         NAMZ USA
# 1        Crude-oil prices are at $35 a barrel and OPEC ...         NAMZ USA
# 2        \nTo the Editor:\n\n\n\nBarry Wulff (Mailbag, ...         NAMZ USA
# 3        Radical changes in energy generation and consu...        NAMZ USA
# 4        To the Editor: I think there is only one criti...        NAMZ USA
# ...                                                    ...              ...
# 2548102  I watched the news and the devastation in Brit...       CANA NAMZ
# 2548103  To the editor:\n\nThe American West is in a me...        NAMZ USA
# 2548104  By meteorological standards, weather condition...        NAMZ USA
# 2548105  DUBUQUE — U.S. Rep. Rod Blum, R-Iowa, met a ho...        NAMZ USA
# 2548106  The top ten news stories of 2015, according to...        NAMZ USA
#
#                           source_name language_code  \
# 0                            Barron's            en
# 1                            Barron's            en
# 2                           Barron's             en
# 3                            Barron's            en
# 4                            Barron's            en
# ...                               ...           ...
# 2548102          West Elgin Chronicle            en
# 2548103              The Western News            en
# 2548104      The Weatherford Democrat            en
# 2548105  Waterloo-Cedar Falls Courier            en
# 2548106              The Express Star            en
#
#                                              region_codes  \
# 0                                              ,usa,namz,
# 1              ,usa,usca,use,usfl,usny,uss,ustx,usw,namz,
# 2                                              ,namz,usa,
# 3
# 4                                              ,usa,namz,
# ...                                                   ...
# 2548102                                  ,cabc,cana,namz,
# 2548103                                        ,usa,namz,
# 2548104                               ,ustx,namz,usa,uss,
# 2548105                               ,usa,usia,namz,usc,
# 2548106  ,usa,paris,eecz,eurz,fra,ilefra,medz,namz,weurz,
#
#                                                 byline  \
# 0
# 1                                     By John Sillin
# 2                                                  NaN
# 3                                 By Matthew C. Klein
# 4
# ...                                                ...
# 2548102                                  Cameron Bain
# 2548103
# 2548104    Breanna Edelstein | Community News Content
# 2548105    THOMAS J. BARTON thomas.barton@thmedia.com
# 2548106  Chanukah Christie | Community News Content
#
#                                                      title  \
# 0                   Barron's Mailbag: Blowing Hot and Cold
# 1        Unleash the Potential: The benefits of buildin...
# 2            \nBarron's Mailbag:\nMore On Global Warming\n
# 3        Climate Change's Risk to Investors --- Why spe...
# 4                      Fossil Fuels Are the Critical Issue
# ...                                                    ...
# 2548102                 Why are we buying Christmas trees?
# 2548103  Megadrought highlights need for water conserva...
# 2548104  Researcher finds that New Hampshire's growing ...
# 2548105                Dubuque town hall puts heat on Blum
# 2548106     Visualizations of the top news stories of 2015
#
#                              publisher_name
# 0                 Dow Jones & Company, Inc.
# 1                       Dow Jones & Company
# 2                       Dow Jones & Company
# 3                 Dow Jones & Company, Inc.
# 4                 Dow Jones & Company, Inc.
# ...                                     ...
# 2548102              Postmedia Network Inc.
# 2548103                      Hagadone Corp.
# 2548104  Community Newspaper Holdings, Inc.
# 2548105                     Lee Enterprises
# 2548106  Community Newspaper Holdings, Inc.
#
# [2548107 rows x 11 columns]

# %%
sample_df=all_df.sample(600)

# %%
sample_df
# Out:
#          index                                      subject_codes  \
# 703875   11427  ,gclimt,genv,gpol,guni,nedc,gcat,gedu,gglobe,g...
# 1221560  25372  ,gclimt,gcycl,gcat,genv,gglobe,gspo,ncat,nfact...
# 399560   21768              ,gqual,gairp,gclimt,gcat,genv,gglobe,
# 689773   28840  ,gcivds,gclimt,gcrim,gcat,gcns,genv,gglobe,gri...
# 1186743  22118                          ,gclimt,gcat,genv,gglobe,
# ...        ...                                                ...
# 386950    9158          ,gsust,gclimt,npag,gcat,genv,gglobe,ncat,
# 767472   12403                     ,gclimt,gcat,genv,gglobe,gwea,
# 2138652  31281  ,gmovie,gclimt,gfesti,gflood,nnam,gcat,gdis,ge...
# 1417980   1794                     ,gclimt,gcat,genv,gglobe,gwea,
# 2227029  25223  ,npress,gclimt,greg,gsust,gcat,genv,gglobe,gpi...
#
#                                                       body  \
# 703875   CORVALLIS, Ore. -- With all the evidence cropp...
# 1221560  The cyclist educated and encouraged people en-...
# 399560   Our news journalists obtained a quote from the...
# 689773   The conference took a day off yesterday, thoug...
# 1186743  Our news editors obtained a quote from the res...
# ...                                                    ...
# 386950   MONTEREY >> Monterey is expected to soon exper...
# 767472   Mwenda was addressing African journalists who ...
# 2138652  The film was directed by Fisher Stevens. It ch...
# 1417980  Previously, officials believed the park 60 mil...
# 2227029  International symposium explores visionary ins...
#
#                                                    snippet  \
# 703875   U-WIRE-03/05/2004-Oregon State U.: COLUMN: Stu...
# 1221560  Cyclist Abid Baig has reportedly undertaken th...
# 399560   2019 JUL 29 (VerticalNews) -- By a News Report...
# 689773   COPENHAGEN — Danish police released hundreds o...
# 1186743  2020 APR 13 (VerticalNews) -- By a News Report...
# ...                                                    ...
# 386950   By Dennis L. Taylor\n\ndtaylor@montereyherald.com
# 767472   Nov 26, 2012 (New Vision/All Africa Global Med...
# 2138652  DiCaprio unveils climate change film 'Before t...
# 1417980  ROCKY MOUNTAIN NATIONAL PARK, Colo.- Geologist...
# 2227029  Announcement of new initiatives to align with ...
#
#                        region_of_origin              source_name  \
# 703875                         NAMZ USA                   U-Wire
# 1221560              ASIA PAKIS SASIAZ     The Balochistan Times
# 399560                        NAMZ USA      Global Warming Focus
# 689773               ASIA SEASIAZ SINGP        TODAY (Singapore)
# 1186743                       NAMZ USA      Global Warming Focus
# ...                                 ...                      ...
# 386950                        NAMZ USA    Monterey County Herald
# 767472              AFRICA SAFR SOUAFR                All Africa
# 2138652                       NAMZ USA          Telegraph Herald
# 1417980                       NAMZ USA         Houston Chronicle
# 2227029  ASIA CHINA CHINAZ EASIA HKONG   Media OutReach Newswire
#
#         language_code                                       region_codes  \
# 703875             en                                ,usa,usor,namz,usw,
# 1221560            en        ,pakis,asiaz,devgcoz,dvpcoz,indsubz,sasiaz,
# 399560             en  ,porl,turk,asiaz,balkz,devgcoz,dvpcoz,eecz,eur...
# 689773             en                 ,den,eecz,eurz,nordz,scandz,weurz,
# 1186743            en  ,china,chinaz,beijin,apacz,asiaz,bric,devgcoz,...
# ...               ...                                                ...
# 386950             en                                         ,usa,namz,
# 767472             en  ,qatar,africaz,doha,jap,kenya,usa,apacz,asiaz,...
# 2138652            en                                         ,usa,namz,
# 1417980            en                                         ,usa,namz,
# 2227029            en  ,china,hkong,apacz,asiaz,bric,chinaz,devgcoz,d...
#
#                                            byline  \
# 703875
# 1221560
# 399560
# 689773
# 1186743
# ...                                           ...
# 386950
# 767472             by Catherine Mwesigwa Kizza
# 2138652                     The Associated Press
# 1417980  JOSEPH B. VERRENGIA; Associated Press
# 2227029
#
#                                                      title  \
# 703875   Oregon State U.: COLUMN: Studying the science ...
# 1221560  Longest and fastest solo bike ride: Abid pedal...
# 399560   Environment - Atmospheric Pollution; Findings ...
# 689773           Nearly 1,000 climate protesters released
# 1186743  Climate Modeling; Chinese Academy of Sciences ...
# ...                                                    ...
# 386950   Environment; Monterey will see more required w...
# 767472             Africa Wants World Carbon Emissions Cut
# 2138652  DiCaprio unveils climate change film 'Before t...
# 1417980  Glacier growth surprises geologists Despite gl...
# 2227029  HKQAA Symposium  Sustainable Finance and Clima...
#
#                        publisher_name
# 703875        M2 Communications, Ltd.
# 1221560      Daily Balochistan Times'
# 399560                    NewsRX, LLC
# 689773            MediaCorp Press Ltd
# 1186743                   NewsRX, LLC
# ...                               ...
# 386950           MediaNews Group Inc.
# 767472        All Africa Global Media
# 2138652  Woodward Communications Inc.
# 1417980   Hearst Communications, Inc.
# 2227029        Media OutReach Limited
#
# [600 rows x 11 columns]

# %%
# pattern = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')


def preprocess_data(df):
    # Here the article's content is in the column named 'content'
    # If it resides under other column name, then change the word content in the next line with
    # the name of your column
    # Remove punctuation characters
    #df['preprocessed_sentence'] = sample_df.body.apply(lambda x: re.sub(r"[^a-zA-Z0-9]", " ", str(x)))
    df['preprocessed_sentence'] = sample_df['body']
    # Removing numbers
    #df['preprocessed_sentence'] = df.preprocessed_sentence.apply(lambda x: re.sub(r"[\d+$]", " ", str(x)))
    # df['preprocessed_sentence']=df['body']
    #Removing new lines and tabs
    df['preprocessed_sentence'] = df.preprocessed_sentence.apply(lambda x: re.sub(r"\n", " ", str(x)))
    df['preprocessed_sentence'] = df.preprocessed_sentence.apply(lambda x: re.sub(r"\t", " ", str(x)))

    # Remove stopwords, lower case all the words and split them into a list of words
    # df['preprocessed_sentence'] = df.preprocessed_sentence.apply(lambda x: pattern.sub('', re.sub(r"[^a-zA-Z0-9]", " ", x).lower()))

    df['processed_word_count'] = df.preprocessed_sentence.apply(lambda x: len(x))
    df = df[df.processed_word_count > 0]

    return df

# %%
temp_df = preprocess_data(sample_df)

# %%
temp_df
# Out:
#          index                                      subject_codes  \
# 703875   11427  ,gclimt,genv,gpol,guni,nedc,gcat,gedu,gglobe,g...
# 1221560  25372  ,gclimt,gcycl,gcat,genv,gglobe,gspo,ncat,nfact...
# 399560   21768              ,gqual,gairp,gclimt,gcat,genv,gglobe,
# 689773   28840  ,gcivds,gclimt,gcrim,gcat,gcns,genv,gglobe,gri...
# 1186743  22118                          ,gclimt,gcat,genv,gglobe,
# ...        ...                                                ...
# 386950    9158          ,gsust,gclimt,npag,gcat,genv,gglobe,ncat,
# 767472   12403                     ,gclimt,gcat,genv,gglobe,gwea,
# 2138652  31281  ,gmovie,gclimt,gfesti,gflood,nnam,gcat,gdis,ge...
# 1417980   1794                     ,gclimt,gcat,genv,gglobe,gwea,
# 2227029  25223  ,npress,gclimt,greg,gsust,gcat,genv,gglobe,gpi...
#
#                                                       body  \
# 703875   CORVALLIS, Ore. -- With all the evidence cropp...
# 1221560  The cyclist educated and encouraged people en-...
# 399560   Our news journalists obtained a quote from the...
# 689773   The conference took a day off yesterday, thoug...
# 1186743  Our news editors obtained a quote from the res...
# ...                                                    ...
# 386950   MONTEREY >> Monterey is expected to soon exper...
# 767472   Mwenda was addressing African journalists who ...
# 2138652  The film was directed by Fisher Stevens. It ch...
# 1417980  Previously, officials believed the park 60 mil...
# 2227029  International symposium explores visionary ins...
#
#                                                    snippet  \
# 703875   U-WIRE-03/05/2004-Oregon State U.: COLUMN: Stu...
# 1221560  Cyclist Abid Baig has reportedly undertaken th...
# 399560   2019 JUL 29 (VerticalNews) -- By a News Report...
# 689773   COPENHAGEN — Danish police released hundreds o...
# 1186743  2020 APR 13 (VerticalNews) -- By a News Report...
# ...                                                    ...
# 386950   By Dennis L. Taylor\n\ndtaylor@montereyherald.com
# 767472   Nov 26, 2012 (New Vision/All Africa Global Med...
# 2138652  DiCaprio unveils climate change film 'Before t...
# 1417980  ROCKY MOUNTAIN NATIONAL PARK, Colo.- Geologist...
# 2227029  Announcement of new initiatives to align with ...
#
#                        region_of_origin              source_name  \
# 703875                         NAMZ USA                   U-Wire
# 1221560              ASIA PAKIS SASIAZ     The Balochistan Times
# 399560                        NAMZ USA      Global Warming Focus
# 689773               ASIA SEASIAZ SINGP        TODAY (Singapore)
# 1186743                       NAMZ USA      Global Warming Focus
# ...                                 ...                      ...
# 386950                        NAMZ USA    Monterey County Herald
# 767472              AFRICA SAFR SOUAFR                All Africa
# 2138652                       NAMZ USA          Telegraph Herald
# 1417980                       NAMZ USA         Houston Chronicle
# 2227029  ASIA CHINA CHINAZ EASIA HKONG   Media OutReach Newswire
#
#         language_code                                       region_codes  \
# 703875             en                                ,usa,usor,namz,usw,
# 1221560            en        ,pakis,asiaz,devgcoz,dvpcoz,indsubz,sasiaz,
# 399560             en  ,porl,turk,asiaz,balkz,devgcoz,dvpcoz,eecz,eur...
# 689773             en                 ,den,eecz,eurz,nordz,scandz,weurz,
# 1186743            en  ,china,chinaz,beijin,apacz,asiaz,bric,devgcoz,...
# ...               ...                                                ...
# 386950             en                                         ,usa,namz,
# 767472             en  ,qatar,africaz,doha,jap,kenya,usa,apacz,asiaz,...
# 2138652            en                                         ,usa,namz,
# 1417980            en                                         ,usa,namz,
# 2227029            en  ,china,hkong,apacz,asiaz,bric,chinaz,devgcoz,d...
#
#                                            byline  \
# 703875
# 1221560
# 399560
# 689773
# 1186743
# ...                                           ...
# 386950
# 767472             by Catherine Mwesigwa Kizza
# 2138652                     The Associated Press
# 1417980  JOSEPH B. VERRENGIA; Associated Press
# 2227029
#
#                                                      title  \
# 703875   Oregon State U.: COLUMN: Studying the science ...
# 1221560  Longest and fastest solo bike ride: Abid pedal...
# 399560   Environment - Atmospheric Pollution; Findings ...
# 689773           Nearly 1,000 climate protesters released
# 1186743  Climate Modeling; Chinese Academy of Sciences ...
# ...                                                    ...
# 386950   Environment; Monterey will see more required w...
# 767472             Africa Wants World Carbon Emissions Cut
# 2138652  DiCaprio unveils climate change film 'Before t...
# 1417980  Glacier growth surprises geologists Despite gl...
# 2227029  HKQAA Symposium  Sustainable Finance and Clima...
#
#                        publisher_name  \
# 703875        M2 Communications, Ltd.
# 1221560      Daily Balochistan Times'
# 399560                    NewsRX, LLC
# 689773            MediaCorp Press Ltd
# 1186743                   NewsRX, LLC
# ...                               ...
# 386950           MediaNews Group Inc.
# 767472        All Africa Global Media
# 2138652  Woodward Communications Inc.
# 1417980   Hearst Communications, Inc.
# 2227029        Media OutReach Limited
#
#                                      preprocessed_sentence  \
# 703875   CORVALLIS, Ore. -- With all the evidence cropp...
# 1221560  The cyclist educated and encouraged people en-...
# 399560   Our news journalists obtained a quote from the...
# 689773   The conference took a day off yesterday, thoug...
# 1186743  Our news editors obtained a quote from the res...
# ...                                                    ...
# 386950   MONTEREY >> Monterey is expected to soon exper...
# 767472   Mwenda was addressing African journalists who ...
# 2138652  The film was directed by Fisher Stevens. It ch...
# 1417980  Previously, officials believed the park 60 mil...
# 2227029  International symposium explores visionary ins...
#
#          processed_word_count
# 703875                   5419
# 1221560                   316
# 399560                   2247
# 689773                    949
# 1186743                  2799
# ...                       ...
# 386950                   4053
# 767472                   6667
# 2138652                  1515
# 1417980                  3156
# 2227029                 31512
#
# [590 rows x 13 columns]

# %%
temp_df[['preprocessed_sentence', 'snippet','title','subject_codes']].to_csv('climate-change-sample.csv')
