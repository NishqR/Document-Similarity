# %%
import os
import string
from time import time
import random

import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from difflib import SequenceMatcher
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from statistics import mean

import gensim
from gensim.models.doc2vec import Doc2Vec
from sentence_transformers import SentenceTransformer

from tensorflow_estimator.python.estimator.canned.dnn import dnn_logit_fn_builder
import tensorflow_hub as hub
import tensorflow as tf

import multiprocessing
from multiprocessing import Pool, cpu_count
import threading

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import sent_tokenize

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('punkt')

#stop_words = stopwords.words('english')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()


def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def preprocess(sentence):
    return [w for w in sentence.lower().split() if w not in stop_words]


if __name__ == "__main__":

    run_relevant = True
    main_start = time() 

    articles_df = pd.read_csv("all_articles.csv")

    if run_relevant == True:

        articles = list(articles_df[articles_df['relevant_campbell'] == 1]['text'])

    else:

        articles = list(articles_df[articles_df['relevant_campbell'] == 0]['text'])        

    

    count = 0
    print("---------------------------- LOADING MODEL---------------------------- ")
    start = time()
    global model
    # This will download and load the pretrained model offered by UKPLab.
    model = SentenceTransformer('bert-base-nli-mean-tokens')
    
    print('MODEL LOADED in %.2f seconds' % (time() - start))
    
    embeddings_dict = {}
    count_dict = {}
    
    for article in articles:
        
        print(f"Doing embeddings for article {count}")
        
        start = time()
        
        sentences = sent_tokenize(article)
        
        for sentence in sentences:
            words_in_sentence = list(sentence.split(" "))
            for word_ in words_in_sentence:

                word_ = word_.lower()
                word_ = word_.strip()
                word_ = word_.replace(" ", "")
                word_ = word_.replace(",", "")
                word_ = word_.replace(".", "")
                word_ = word_.replace(":", "")

                if lemmatizer.lemmatize(word_) != 'ha' or lemmatizer.lemmatize(word_) != 'wa':
                    word_ = lemmatizer.lemmatize(word_)

                if word_ not in stop_words and word_ not in string.punctuation:
                    if word_ not in embeddings_dict.keys():
                        #embeddings_dict[word_] = model.encode(word_)
                        embeddings_dict[word_] = ""
                        count_dict[word_] = 1

                    else:
                        count_dict[word_] += 1

        count+=1
        print('Cell took %.2f seconds to run.' % (time() - start))

    #print(sorted(((v, k) for k, v in count_dict.items()), reverse=True))
    
    output_df = pd.DataFrame(pd.Series(count_dict))
    
    if run_relevant == True:
        output_df.sort_values(by=[0], ascending=False).to_csv("relevant_words_count.csv")
        
    else:
        output_df.sort_values(by=[0], ascending=False).to_csv("irrelevant_words_count.csv")
    print('Script took %.2f minutes to run.' % ((time() - main_start)/60))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nishq\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nishq\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nishq\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\nishq\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nishq\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------- LOADING MODEL----------------------------
# MODEL LOADED in 1.63 seconds
# Doing embeddings for article 0
# Cell took 1.26 seconds to run.
# Doing embeddings for article 1
# Cell took 0.00 seconds to run.
# Doing embeddings for article 2
# Cell took 0.00 seconds to run.
# Doing embeddings for article 3
# Cell took 0.00 seconds to run.
# Doing embeddings for article 4
# Cell took 0.00 seconds to run.
# Doing embeddings for article 5
# Cell took 0.00 seconds to run.
# Doing embeddings for article 6
# Cell took 0.00 seconds to run.
# Doing embeddings for article 7
# Cell took 0.00 seconds to run.
# Doing embeddings for article 8
# Cell took 0.00 seconds to run.
# Doing embeddings for article 9
# Cell took 0.00 seconds to run.
# Doing embeddings for article 10
# Cell took 0.01 seconds to run.
# Doing embeddings for article 11
# Cell took 0.00 seconds to run.
# Doing embeddings for article 12
# Cell took 0.00 seconds to run.
# Doing embeddings for article 13
# Cell took 0.00 seconds to run.
# Doing embeddings for article 14
# Cell took 0.00 seconds to run.
# Doing embeddings for article 15
# Cell took 0.00 seconds to run.
# Doing embeddings for article 16
# Cell took 0.00 seconds to run.
# Doing embeddings for article 17
# Cell took 0.00 seconds to run.
# Doing embeddings for article 18
# Cell took 0.00 seconds to run.
# Doing embeddings for article 19
# Cell took 0.00 seconds to run.
# Doing embeddings for article 20
# Cell took 0.00 seconds to run.
# Doing embeddings for article 21
# Cell took 0.00 seconds to run.
# Doing embeddings for article 22
# Cell took 0.01 seconds to run.
# Doing embeddings for article 23
# Cell took 0.00 seconds to run.
# Doing embeddings for article 24
# Cell took 0.00 seconds to run.
# Doing embeddings for article 25
# Cell took 0.00 seconds to run.
# Doing embeddings for article 26
# Cell took 0.01 seconds to run.
# Doing embeddings for article 27
# Cell took 0.00 seconds to run.
# Doing embeddings for article 28
# Cell took 0.00 seconds to run.
# Doing embeddings for article 29
# Cell took 0.00 seconds to run.
# Doing embeddings for article 30
# Cell took 0.00 seconds to run.
# Doing embeddings for article 31
# Cell took 0.00 seconds to run.
# Doing embeddings for article 32
# Cell took 0.00 seconds to run.
# Doing embeddings for article 33
# Cell took 0.00 seconds to run.
# Doing embeddings for article 34
# Cell took 0.00 seconds to run.
# Doing embeddings for article 35
# Cell took 0.00 seconds to run.
# Doing embeddings for article 36
# Cell took 0.00 seconds to run.
# Doing embeddings for article 37
# Cell took 0.00 seconds to run.
# Doing embeddings for article 38
# Cell took 0.00 seconds to run.
# Doing embeddings for article 39
# Cell took 0.00 seconds to run.
# Doing embeddings for article 40
# Cell took 0.00 seconds to run.
# Doing embeddings for article 41
# Cell took 0.00 seconds to run.
# Doing embeddings for article 42
# Cell took 0.00 seconds to run.
# Doing embeddings for article 43
# Cell took 0.00 seconds to run.
# Doing embeddings for article 44
# Cell took 0.00 seconds to run.
# Doing embeddings for article 45
# Cell took 0.00 seconds to run.
# Doing embeddings for article 46
# Cell took 0.00 seconds to run.
# Doing embeddings for article 47
# Cell took 0.00 seconds to run.
# Doing embeddings for article 48
# Cell took 0.00 seconds to run.
# Doing embeddings for article 49
# Cell took 0.01 seconds to run.
# Doing embeddings for article 50
# Cell took 0.00 seconds to run.
# Doing embeddings for article 51
# Cell took 0.00 seconds to run.
# Doing embeddings for article 52
# Cell took 0.00 seconds to run.
# Doing embeddings for article 53
# Cell took 0.00 seconds to run.
# Doing embeddings for article 54
# Cell took 0.01 seconds to run.
# Doing embeddings for article 55
# Cell took 0.00 seconds to run.
# Doing embeddings for article 56
# Cell took 0.00 seconds to run.
# Doing embeddings for article 57
# Cell took 0.00 seconds to run.
# Doing embeddings for article 58
# Cell took 0.00 seconds to run.
# Doing embeddings for article 59
# Cell took 0.00 seconds to run.
# Doing embeddings for article 60
# Cell took 0.00 seconds to run.
# Doing embeddings for article 61
# Cell took 0.00 seconds to run.
# Doing embeddings for article 62
# Cell took 0.00 seconds to run.
# Doing embeddings for article 63
# Cell took 0.01 seconds to run.
# Doing embeddings for article 64
# Cell took 0.00 seconds to run.
# Doing embeddings for article 65
# Cell took 0.00 seconds to run.
# Doing embeddings for article 66
# Cell took 0.01 seconds to run.
# Doing embeddings for article 67
# Cell took 0.00 seconds to run.
# Doing embeddings for article 68
# Cell took 0.00 seconds to run.
# [(158, 'pension'), (148, 'said'), (131, 'year'), (131, 'retirement'), (115, 'loan'), (111, 'mortgage'), (99, 'money'), (95, 'rate'), (93, 'student'), (90, 'pay'), (89, 'ha'), (83, 'people'), (82, 'plan'), (81, 'tax'), (78, 'debt'), (77, 'also'), (75, 'per'), (74, 'say'), (73, 'financial'), (70, 'new'), (70, '--'), (69, 'would'), (69, 'state'), (69, 'income'), (67, 'saving'), (65, 'may'), (65, 'home'), (61, 'worker'), (61, 'make'), (59, 'interest'), (59, 'could'), (58, 'health'), (58, 'cent'), (56, 'one'), (56, 'need'), (56, 'investment'), (56, 'card'), (55, 'credit'), (54, 'month'), (53, 'wa'), (51, 'time'), (50, 'get'), (50, 'cost'), (48, 'help'), (47, 'service'), (47, 'many'), (46, 'still'), (46, 'million'), (45, 'price'), (45, 'age'), (42, 'benefit'), (41, 'woman'), (40, 'want'), (40, 'take'), (40, 'fund'), (39, 'scheme'), (38, 'news'), (38, 'much'), (38, 'first'), (36, 'program'), (36, 'payment'), (36, 'market'), (36, 'last'), (35, 'save'), (34, 'higher'), (34, 'company'), (34, 'change'), (34, 'bank'), (34, 'according'), (33, 'bill'), (33, 'american'), (32, 'work'), (32, 'two'), (32, 'today'), (32, 'report'), (32, 'job'), (32, 'care'), (31, 'way'), (31, 'government'), (31, 'good'), (31, 'asset'), (30, 'u'), (30, 'research'), (30, 'fee'), (30, 'family'), (30, 'education'), (29, 'water'), (29, 'information'), (29, 'go'), (29, 'employer'), (28, 'lower'), (28, 'charge'), (27, 'support'), (27, 'next'), (27, 'mean'), (27, 'lender'), (27, 'le'), (27, 'account'), (26, 'working'), (26, 'repayment'), (26, 'provide'), (26, 'day'), (26, 'cash'), (26, 'car'), (26, 'back'), (25, 'think'), (25, 'risk'), (25, 'retire'), (25, 'option'), (25, 'estate'), (25, 'customer'), (25, 'child'), (25, 'better'), (25, 'advice'), (24, 'use'), (24, 'security'), (24, 'read'), (24, 'like'), (24, 'life'), (24, 'business'), (24, 'average'), (24, 'adviser'), (23, 'well'), (23, 'number'), (23, 'member'), (23, 'know'), (23, 'increase'), (23, 'finance'), (23, 'ensure'), (22, 'release'), (22, 'even'), (22, 'enough'), (22, 'consumer'), (22, 'area'), (22, 'amount'), (22, 'across'), (22, 'able'), (21, 'used'), (21, 'thing'), (21, 'spend'), (21, 'paying'), (21, 'likely'), (21, 'important'), (21, 'housing'), (21, 'high'), (21, 'found'), (21, 'electric'), (21, 'current'), (21, 'come'), (21, 'borrower'), (21, 'around'), (20, 'value'), (20, 'start'), (20, 'since'), (20, 'relief'), (20, 'part'), (20, 'mr'), (20, 'issue'), (20, 'insurance'), (20, 'federal'), (20, 'equity'), (20, 'end'), (20, 'economic'), (20, 'cut'), (19, 'without'), (19, 'week'), (19, 'vehicle'), (19, 'public'), (19, 'policy'), (19, 'offer'), (19, 'give'), (19, 'contribution'), (19, 'consider'), (19, 'claim'), (19, 'another'), (18, 'whether'), (18, 'property'), (18, 'professional'), (18, 'president'), (18, 'portfolio'), (18, 'period'), (18, 'pandemic'), (18, 'paid'), (18, 'men'), (18, 'lot'), (18, 'leave'), (18, 'firm'), (18, 'california'), (18, 'act'), (18, '"we'), (17, 'sum'), (17, 'set'), (17, 'sector'), (17, 'rule'), (17, 'might'), (17, 'low'), (17, 'long'), (17, 'law'), (17, 'landlord'), (17, 'inflation'), (17, 'free'), (17, '"the'), (16, 'study'), (16, 'see'), (16, 'right'), (16, 'recent'), (16, 'receive'), (16, 'put'), (16, 'must'), (16, 'monthly'), (16, 'making'), (16, 'lump'), (16, 'look'), (16, 'individual'), (16, 'including'), (16, 'house'), (16, 'group'), (16, 'future'), (16, 'find'), (16, 'enrollment'), (16, 'deal'), (16, 'article'), (16, 'allow'), (15, 'understand'), (15, 'talk'), (15, 'show'), (15, 'reason'), (15, 'protection'), (15, 'product'), (15, 'planning'), (15, 'personal'), (15, 'parent'), (15, 'manager'), (15, 'made'), (15, 'living'), (15, 'half'), (15, 'going'), (15, 'gas'), (15, 'full'), (15, 'employee'), (15, 'doe'), (15, 'crisis'), (15, 'buyer'), (15, 'billion'), (15, 'balance'), (15, 'available'), (15, 'additional'), (14, 'visit'), (14, 'university'), (14, 'taxpayer'), (14, 'stock'), (14, 'source'), (14, 'social'), (14, 'secure'), (14, 'provider'), (14, 'online'), (14, 'older') ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13864/3882793612.py in <module>
#     119     print(sorted(((v, k) for k, v in count_dict.items()), reverse=True))
#     120
# --> 121     output_df = pd.DataFrame(count_dict)
#     122     #output_df.to_csv("output.csv")
#     123     print('Script took %.2f minutes to run.' % ((time() - main_start)/60))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Out:
#               0
# pension     158
# said        148
# retirement  131
# year        131
# loan        115
# ...         ...
# anyway        1
# queried       1
# came          1
# admitted      1
# million?      1
#
# [5392 rows x 1 columns]
